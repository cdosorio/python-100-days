# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Explore data

# %%
df = pd.read_csv('salaries_by_college_major_updated.csv')
df.head()
# Out:
#                                 Undergraduate Major  Starting Median Salary  \
# 0                             Petroleum Engineering               93,200.00
# 1      Operations Research & Industrial Engineering               84,800.00
# 2  Electrical Engineering & Computer Science (EECS)              108,500.00
# 3                                Interaction Design               68,300.00
# 4                                 Public Accounting               59,800.00
#
#    Mid-Career Median Salary
# 0                187,300.00
# 1                170,400.00
# 2                159,300.00
# 3                155,800.00
# 4                147,700.00

# %%
df.shape
# Out:
# (827, 3)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary'],
#       dtype='object')

# %% [markdown]
# # Clean data

# %%
df.isna()

# %%
df.tail()
# Out:
#            Undergraduate Major  Starting Median Salary  \
# 822          Outdoor Education               37,400.00
# 823  Early Childhood Education               36,100.00
# 824              Mental Health               36,900.00
# 825          Medical Assisting               36,000.00
# 826              Metalsmithing               40,000.00
#
#      Mid-Career Median Salary
# 822                 46,300.00
# 823                 45,400.00
# 824                 45,000.00
# 825                 44,800.00
# 826                 40,300.00

# %%
clean_df = df.dropna()
clean_df.tail()
# Out:
#            Undergraduate Major  Starting Median Salary  \
# 822          Outdoor Education               37,400.00
# 823  Early Childhood Education               36,100.00
# 824              Mental Health               36,900.00
# 825          Medical Assisting               36,000.00
# 826              Metalsmithing               40,000.00
#
#      Mid-Career Median Salary
# 822                 46,300.00
# 823                 45,400.00
# 824                 45,000.00
# 825                 44,800.00
# 826                 40,300.00

# %% [markdown]
# # major with the highest starting salary

# %%
clean_df['Starting Median Salary'].idxmax()
# Out:
# 2

# %%
clean_df['Undergraduate Major'].loc[43]
# Out:
# 'Quantitative Business Analysis'

# %%
clean_df.loc[43]
# Out:
# Undergraduate Major         Quantitative Business Analysis
# Starting Median Salary                           74,000.00
# Mid-Career Median Salary                        125,400.00
# Name: 43, dtype: object

# %% [markdown]
# # Sort by salary

# %%
highest_df = clean_df.sort_values('Starting Median Salary', ascending=False)
highest_df.head(50)
# Out:
#                          Undergraduate Major  Starting Median Salary  \
# 826                            Metalsmithing               40,000.00
# 759                        Church Ministries               40,000.00
# 811                               Counseling               39,900.00
# 755                          Social Services               39,900.00
# 562                         Health & Fitness               39,800.00
# 722                      Wildlife Management               39,700.00
# 735                        Paralegal Studies               39,600.00
# 545         Graphics Technology & Management               39,500.00
# 795                   Therapeutic Recreation               39,500.00
# 588                          Arts Management               39,400.00
# 788                           Family Studies               39,200.00
# 821                Rehabilitation Counseling               39,200.00
# 457                           Museum Studies               38,900.00
# 614                         Child Psychology               38,900.00
# 809          Hospitality & The Culinary Arts               38,800.00
# 799                    Office Administration               38,700.00
# 779                        Pastoral Ministry               38,700.00
# 810                      Human Services (HS)               38,700.00
# 583                Applied Behavior Analysis               38,700.00
# 747     Health & Physical Education Teaching               38,700.00
# 805                      Christian Education               38,700.00
# 798                         Social Work (SW)               38,600.00
# 812                     Recreational Therapy               38,400.00
# 715                              Printmaking               38,400.00
# 794                 Developmental Psychology               38,200.00
# 785                  Legal Assistant Studies               38,100.00
# 753               Health & Human Performance               38,100.00
# 789                       Christian Ministry               38,100.00
# 817   Early Childhood & Elementary Education               38,000.00
# 819                        Addiction Studies               38,000.00
# 606                 Health Teacher Education               37,900.00
# 807                     Baking & Pastry Arts               37,500.00
# 380                           Speech & Drama               37,500.00
# 822                        Outdoor Education               37,400.00
# 813                        Child Development               37,400.00
# 802                           Youth Ministry               37,400.00
# 713                                  Drawing               37,400.00
# 814                   Educational Psychology               36,900.00
# 824                            Mental Health               36,900.00
# 800                                 Ministry               36,700.00
# 820                   Child & Family Studies               36,400.00
# 767  Biblical Studies & Practical Ministries               36,400.00
# 816                 Mental Health Counseling               36,100.00
# 823                Early Childhood Education               36,100.00
# 825                        Medical Assisting               36,000.00
# 756                  Rehabilitation Services               35,800.00
# 818                           Equine Studies               35,700.00
# 764              Psychology & Human Services               35,600.00
# 593                   Painting & Printmaking               34,700.00
# 804                            Voice & Opera               34,500.00
#
#      Mid-Career Median Salary
# 826                 40,300.00
# 759                 59,900.00
# 811                 51,700.00
# 755                 60,500.00
# 562                 75,600.00
# 722                 64,100.00
# 735                 63,100.00
# 545                 76,800.00
# 795                 54,900.00
# 588                 73,800.00
# 788                 56,800.00
# 821                 46,400.00
# 457                 82,700.00
# 614                 72,200.00
# 809                 52,900.00
# 799                 54,500.00
# 779                 58,000.00
# 810                 52,500.00
# 583                 74,200.00
# 747                 61,900.00
# 805                 53,200.00
# 798                 54,600.00
# 812                 51,600.00
# 715                 64,300.00
# 794                 55,000.00
# 785                 57,100.00
# 753                 61,100.00
# 789                 56,400.00
# 817                 48,400.00
# 819                 47,000.00
# 606                 72,600.00
# 807                 53,000.00
# 380                 86,800.00
# 822                 46,300.00
# 813                 51,400.00
# 802                 54,200.00
# 713                 64,800.00
# 814                 51,200.00
# 824                 45,000.00
# 800                 54,300.00
# 820                 46,500.00
# 767                 58,900.00
# 816                 50,000.00
# 823                 45,400.00
# 825                 44,800.00
# 756                 60,200.00
# 818                 47,100.00
# 764                 59,400.00
# 593                 73,600.00
# 804                 53,300.00

# %% [markdown]
# # Lowest starting salary.

# %%
clean_df.loc[clean_df['Mid-Career Median Salary'].idxmin()]
# Out:
# Undergraduate Major         Metalsmithing
# Starting Median Salary          40,000.00
# Mid-Career Median Salary        40,300.00
# Name: 826, dtype: object

# %% [markdown]
# # Lowest Risk Majors
# add a column

# %%
spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
clean_df.insert(1, 'Spread', spread_col)
clean_df.head()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
# 3           Anthropology  104200.0                 36800.0
# 4           Architecture   85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# 3                           138000.0      HASS
# 4                           136000.0  Business

# %%
high_risk = clean_df.sort_values('Spread', ascending=False)
high_risk[['Undergraduate Major', 'Spread']].head()
# Out:
#    Undergraduate Major    Spread
# 17           Economics  159400.0
# 22             Finance  147800.0
# 37                Math  137800.0
# 36           Marketing  132900.0
# 42          Philosophy  132500.0

# %% [markdown]
# # Grouping

# %%
clean_df.groupby('Group').mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-59bc06db6f6b> in <module>()
# ----> 1 clean_df.groupby('Group').mean()
#       2
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
#     896                 mutated=self.mutated,
# --> 897                 dropna=self.dropna,
#     898             )
#     899
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     860                 in_axis, level, gpr = False, gpr, None
#     861             else:
# --> 862                 raise KeyError(gpr)
#     863         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     864             # Add key to exclusions
#
# KeyError: 'Group'
